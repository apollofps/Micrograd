# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
# %matplotlib inline

np.random.seed(1337)
random.seed(1337)

X, y = make_moons(n_samples=100, noise=0.1)
y = y * 2 - 1  # make y be -1 or 1

df = pd.DataFrame(np.hstack((X, y.reshape(-1, 1))), columns=['x1', 'x2', 'y'])
df.to_csv('moons_dataset.csv', index=False)

plt.figure(figsize=(5, 5))
plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap='jet')
plt.title("Moons Dataset")
plt.show()

# %%
import subprocess

# Run C# training script
result = subprocess.run(["dotnet", "run"], capture_output=True, text=True)
print(result.stdout)
# Out:
# Step 0: Loss = 0.39158697673009574, Accuracy = 85%
# Step 1: Loss = 0.5003258778704281, Accuracy = 82%
# Step 2: Loss = 0.5493949937743696, Accuracy = 79%
# Step 3: Loss = 0.8258329572850654, Accuracy = 81%
# Step 4: Loss = 0.3807915354183841, Accuracy = 86%
# Step 5: Loss = 0.2745044241032546, Accuracy = 89%
# Step 6: Loss = 0.2700150387739621, Accuracy = 89%
# Step 7: Loss = 0.25804675138682726, Accuracy = 89%
# Step 8: Loss = 0.3067428196766203, Accuracy = 88%
# Step 9: Loss = 0.23454813487098164, Accuracy = 90%
# Step 10: Loss = 0.31722178795575806, Accuracy = 88%
# Step 11: Loss = 0.1686181180939318, Accuracy = 94%
# Step 12: Loss = 0.1914924311488818, Accuracy = 95%
# Step 13: Loss = 0.3194510097164268, Accuracy = 87%
# Step 14: Loss = 0.25594663695889286, Accuracy = 89%
# Step 15: Loss = 0.13329391343988145, Accuracy = 96%
# Step 16: Loss = 0.15869348831451835, Accuracy = 95%
# Step 17: Loss = 0.18584880431642864, Accuracy = 96%
# Step 18: Loss = 0.39139114406558656, Accuracy = 86%
# Step 19: Loss = 0.1611278088605502, Accuracy = 94%
# Step 20: Loss = 0.11451653544830265, Accuracy = 96%
# Step 21: Loss = 0.11817020827716156, Accuracy = 95%
# Step 22: Loss = 0.12653981618653962, Accuracy = 96%
# Step 23: Loss = 0.1265629730242399, Accuracy = 95%
# Step 24: Loss = 0.06523688381545073, Accuracy = 99%
# Step 25: Loss = 0.06557836611345169, Accuracy = 97%
# Step 26: Loss = 0.10404640568860135, Accuracy = 96%
# Step 27: Loss = 0.23376115550987908, Accuracy = 93%
# Step 28: Loss = 0.09572807113093765, Accuracy = 97%
# Step 29: Loss = 0.06442229552335868, Accuracy = 99%
# Step 30: Loss = 0.08840687164510638, Accuracy = 96%
# Step 31: Loss = 0.06562730967129678, Accuracy = 99%
# Step 32: Loss = 0.07101769995262619, Accuracy = 97%
# Step 33: Loss = 0.047720695539667686, Accuracy = 100%
# Step 34: Loss = 0.055043585953861135, Accuracy = 97%
# Step 35: Loss = 0.04464675226480587, Accuracy = 100%
# Step 36: Loss = 0.07855342990905151, Accuracy = 97%
# Step 37: Loss = 0.03181993245718562, Accuracy = 100%
# Step 38: Loss = 0.030533533491430107, Accuracy = 100%
# Step 39: Loss = 0.03272479621295988, Accuracy = 99%
# Step 40: Loss = 0.0594524807325591, Accuracy = 100%
# Step 41: Loss = 0.16938398363609822, Accuracy = 95%
# Step 42: Loss = 0.08745642831297437, Accuracy = 97%
# Step 43: Loss = 0.03213070211477028, Accuracy = 99%
# Step 44: Loss = 0.04495057640318559, Accuracy = 100%
# Step 45: Loss = 0.06989290788537902, Accuracy = 97%
# Step 46: Loss = 0.02479587673282468, Accuracy = 100%
# Step 47: Loss = 0.02229095067709569, Accuracy = 100%
# Step 48: Loss = 0.021731776776512394, Accuracy = 100%
# Step 49: Loss = 0.020247896429531474, Accuracy = 100%
# Step 50: Loss = 0.038549869104926526, Accuracy = 100%
# Step 51: Loss = 0.0658088609611577, Accuracy = 97%
# Step 52: Loss = 0.024109732568884247, Accuracy = 100%
# Step 53: Loss = 0.033353785916898304, Accuracy = 100%
# Step 54: Loss = 0.05106367846312512, Accuracy = 98%
# Step 55: Loss = 0.021190895978315867, Accuracy = 100%
# Step 56: Loss = 0.023348640406599862, Accuracy = 100%
# Step 57: Loss = 0.04571741050498533, Accuracy = 98%
# Step 58: Loss = 0.02251628969250763, Accuracy = 100%
# Step 59: Loss = 0.024123260067758473, Accuracy = 100%
# Step 60: Loss = 0.04247985437651072, Accuracy = 98%
# Step 61: Loss = 0.02119241533396133, Accuracy = 100%
# Step 62: Loss = 0.016296636463295374, Accuracy = 100%
# Step 63: Loss = 0.022045325841366543, Accuracy = 100%
# Step 64: Loss = 0.014406743289609055, Accuracy = 100%
# Step 65: Loss = 0.016832662551145815, Accuracy = 100%
# Step 66: Loss = 0.019234103282822046, Accuracy = 100%
# Step 67: Loss = 0.024257615552849054, Accuracy = 100%
# Step 68: Loss = 0.014138323650825702, Accuracy = 100%
# Step 69: Loss = 0.016072176770706482, Accuracy = 100%
# Step 70: Loss = 0.016825724947965453, Accuracy = 100%
# Step 71: Loss = 0.020017296258293307, Accuracy = 100%
# Step 72: Loss = 0.01419645932190739, Accuracy = 100%
# Step 73: Loss = 0.015061620563295408, Accuracy = 100%
# Step 74: Loss = 0.01959283484769921, Accuracy = 100%
# Step 75: Loss = 0.014262628609860646, Accuracy = 100%
# Step 76: Loss = 0.014087032991742132, Accuracy = 100%
# Step 77: Loss = 0.015755514767820913, Accuracy = 100%
# Step 78: Loss = 0.01416292408196532, Accuracy = 100%
# Step 79: Loss = 0.013553732370940768, Accuracy = 100%
# Step 80: Loss = 0.014288028071793687, Accuracy = 100%
# Step 81: Loss = 0.013151750765828508, Accuracy = 100%
# Step 82: Loss = 0.013107333279667874, Accuracy = 100%
# Step 83: Loss = 0.013037846999803777, Accuracy = 100%
# Step 84: Loss = 0.012955689689503285, Accuracy = 100%
# Step 85: Loss = 0.014735837275015689, Accuracy = 100%
# Step 86: Loss = 0.014143777049778901, Accuracy = 100%
# Step 87: Loss = 0.012990464974266808, Accuracy = 100%
# Step 88: Loss = 0.014008382094697087, Accuracy = 100%
# Step 89: Loss = 0.014020101835839903, Accuracy = 100%
# Step 90: Loss = 0.012998876115446487, Accuracy = 100%
# Step 91: Loss = 0.013397859120317103, Accuracy = 100%
# Step 92: Loss = 0.013915514485663569, Accuracy = 100%
# Step 93: Loss = 0.013035043145831163, Accuracy = 100%
# Step 94: Loss = 0.012883382586923672, Accuracy = 100%
# Step 95: Loss = 0.013085684671076691, Accuracy = 100%
# Step 96: Loss = 0.012558213894797766, Accuracy = 100%
# Step 97: Loss = 0.012505773518621418, Accuracy = 100%
# Step 98: Loss = 0.01245727755092932, Accuracy = 100%
# Step 99: Loss = 0.012412599418986795, Accuracy = 100%
# Training complete. Logs saved to training_logs.csv.
# Decision boundary data saved to decision_boundary.csv.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load training logs
df = pd.read_csv("training_logs.csv")

# Plot loss curve
plt.figure(figsize=(6,4))
plt.plot(df["Step"], df["Loss"], label="Loss", color="blue")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training Loss Curve")
plt.legend()
plt.show()

# Plot accuracy curve
plt.figure(figsize=(6,4))
plt.plot(df["Step"], df["Accuracy"], label="Accuracy", color="green")
plt.xlabel("Step")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy Curve")
plt.legend()
plt.show()

# %%
boundary_df = pd.read_csv('decision_boundary.csv')

# Load the moon dataset.
moon_df = pd.read_csv('moons_dataset.csv')
print("Columns in moons_dataset.csv:", moon_df.columns)  # Verify the columns

# Get unique x and y values for the decision boundary grid.
x_unique = np.sort(boundary_df['x'].unique())
y_unique = np.sort(boundary_df['y'].unique())

# Reshape the decision values into a grid.
Z = boundary_df['decision'].values.reshape(len(y_unique), len(x_unique))

# Create a mesh grid for plotting.
xx, yy = np.meshgrid(x_unique, y_unique)

# Plot the decision boundary using contourf.
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)

# Overlay the moon dataset points using the correct column 'y' for color.
plt.scatter(moon_df['x1'], moon_df['x2'], c=moon_df['y'], cmap=plt.cm.Spectral, edgecolor='k', s=40)

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Decision Boundary and Moon Data")
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()
# Out:
# Columns in moons_dataset.csv: Index(['x1', 'x2', 'y'], dtype='object')
