# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
# %matplotlib inline

np.random.seed(1337)
random.seed(1337)

X, y = make_moons(n_samples=100, noise=0.2)
y = y * 2 - 1  # make y be -1 or 1

df = pd.DataFrame(np.hstack((X, y.reshape(-1, 1))), columns=['x1', 'x2', 'y'])
df.to_csv('moons_dataset.csv', index=False)

plt.figure(figsize=(5, 5))
plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap='jet')
plt.title("Moons Dataset")
plt.show()

# %%
import subprocess

# Run C# training script
result = subprocess.run(["dotnet", "run"], capture_output=True, text=True)
print(result.stdout)
# Out:
# Step 0: Loss = 1.580503618650298, Accuracy = 36%
# Step 1: Loss = 0.7045686621562677, Accuracy = 76%
# Step 2: Loss = 0.5047405539563415, Accuracy = 79%
# Step 3: Loss = 0.9793104133118141, Accuracy = 76%
# Step 4: Loss = 0.3920612584015568, Accuracy = 84%
# Step 5: Loss = 0.3786085723328992, Accuracy = 87%
# Step 6: Loss = 0.3148203207088419, Accuracy = 87%
# Step 7: Loss = 0.4373501057079937, Accuracy = 85%
# Step 8: Loss = 0.28110767602983733, Accuracy = 89%
# Step 9: Loss = 0.38152221105016404, Accuracy = 85%
# Step 10: Loss = 0.243123780886472, Accuracy = 90%
# Step 11: Loss = 0.3419043791678865, Accuracy = 88%
# Step 12: Loss = 0.23607117167642339, Accuracy = 89%
# Step 13: Loss = 0.3326565555656861, Accuracy = 88%
# Step 14: Loss = 0.20559225484556098, Accuracy = 93%
# Step 15: Loss = 0.24576808082704554, Accuracy = 90%
# Step 16: Loss = 0.2532092768645471, Accuracy = 90%
# Step 17: Loss = 0.5020732336813688, Accuracy = 85%
# Step 18: Loss = 0.19806393210711556, Accuracy = 93%
# Step 19: Loss = 0.14479411427188815, Accuracy = 95%
# Step 20: Loss = 0.14557185445921725, Accuracy = 95%
# Step 21: Loss = 0.20440234790997358, Accuracy = 91%
# Step 22: Loss = 0.31782009257941257, Accuracy = 90%
# Step 23: Loss = 0.16054835188535277, Accuracy = 94%
# Step 24: Loss = 0.13211564464578682, Accuracy = 97%
# Step 25: Loss = 0.1498130222027803, Accuracy = 93%
# Step 26: Loss = 0.11874072151335122, Accuracy = 98%
# Step 27: Loss = 0.14144339481554918, Accuracy = 95%
# Step 28: Loss = 0.11264305858437247, Accuracy = 98%
# Step 29: Loss = 0.12126752084113535, Accuracy = 95%
# Step 30: Loss = 0.12879635521204452, Accuracy = 96%
# Step 31: Loss = 0.18871071770911388, Accuracy = 95%
# Step 32: Loss = 0.12474412627261991, Accuracy = 95%
# Step 33: Loss = 0.12494811394695313, Accuracy = 97%
# Step 34: Loss = 0.15161687577462993, Accuracy = 94%
# Step 79: Loss = 0.06305794612744885, Accuracy = 98%
# Step 80: Loss = 0.0630420607956154, Accuracy = 99%
# Step 81: Loss = 0.06314424545765489, Accuracy = 98%
# Step 82: Loss = 0.062346126282756126, Accuracy = 99%
# Step 83: Loss = 0.06218298983751576, Accuracy = 98%
# Step 84: Loss = 0.06270255940878451, Accuracy = 99%
# Step 85: Loss = 0.062313911826349655, Accuracy = 98%
# Step 86: Loss = 0.061862892501080916, Accuracy = 99%
# Step 87: Loss = 0.06262459073172369, Accuracy = 98%
# Step 88: Loss = 0.06137469379776653, Accuracy = 99%
# Step 89: Loss = 0.06162345431473547, Accuracy = 98%
# Step 90: Loss = 0.06146349074505023, Accuracy = 99%
# Step 91: Loss = 0.061624297745348736, Accuracy = 98%
# Step 92: Loss = 0.06070748450679818, Accuracy = 99%
# Step 93: Loss = 0.06066134339819927, Accuracy = 98%
# Step 94: Loss = 0.060615288768408104, Accuracy = 98%
# Step 95: Loss = 0.06087122317235707, Accuracy = 99%
# Step 96: Loss = 0.060730505621521214, Accuracy = 98%
# Step 97: Loss = 0.06060006020090544, Accuracy = 99%
# Step 98: Loss = 0.06039661095982033, Accuracy = 99%
# Step 99: Loss = 0.060240892400694024, Accuracy = 99%
# Training complete. Logs saved to training_logs.csv.
# Decision boundary data saved to decision_boundary.csv.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load training logs
df = pd.read_csv("training_logs.csv")

# Plot loss curve
plt.figure(figsize=(6,4))
plt.plot(df["Step"], df["Loss"], label="Loss", color="blue")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training Loss Curve")
plt.legend()
plt.show()

# Plot accuracy curve
plt.figure(figsize=(6,4))
plt.plot(df["Step"], df["Accuracy"], label="Accuracy", color="green")
plt.xlabel("Step")
plt.ylabel("Accuracy (%)")
plt.title("Training Accuracy Curve")
plt.legend()
plt.show()

# %%
boundary_df = pd.read_csv('decision_boundary.csv')

# Load the moon dataset.
moon_df = pd.read_csv('moons_dataset.csv')
print("Columns in moons_dataset.csv:", moon_df.columns)  # Verify the columns

# Get unique x and y values for the decision boundary grid.
x_unique = np.sort(boundary_df['x'].unique())
y_unique = np.sort(boundary_df['y'].unique())

# Reshape the decision values into a grid.
Z = boundary_df['decision'].values.reshape(len(y_unique), len(x_unique))

# Create a mesh grid for plotting.
xx, yy = np.meshgrid(x_unique, y_unique)

# Plot the decision boundary using contourf.
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)

# Overlay the moon dataset points using the correct column 'y' for color.
plt.scatter(moon_df['x1'], moon_df['x2'], c=moon_df['y'], cmap=plt.cm.Spectral, edgecolor='k', s=40)

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Decision Boundary and Moon Data")
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.show()
# Out:
# Columns in moons_dataset.csv: Index(['x1', 'x2', 'y'], dtype='object')
